# %% [markdown]
# Importowanie bibliotek

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import missingno as msno
from fancyimpute import IterativeImputer
from scipy import stats
from geopandas import GeoDataFrame
from shapely.geometry import Point
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from scipy.stats import shapiro
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score as sklearn_silhouette_score
from sklearn.cluster import DBSCAN
import plotly.express as px
from sklearn.cluster import SpectralClustering

# %% [markdown]
# Uploadowanie danych

# %%
excel_file='/Users/a123456/Downloads/doi_10-4/geneticdata_with_coordinates.xlsx'
sheet_raw='allrawdata'

df=pd.read_excel(excel_file,sheet_raw)
microsatellites = df.drop(columns=['Sample','Longitude','Latitude','sex','age'])

coordinates = df[['Longitude','Latitude']]
scaler = StandardScaler()
scaled_coordinates = scaler.fit_transform(coordinates)

# %%
microsatellites.describe()
# Out:
#             DGN14     DGN14.1    REN69B24  REN69B24.1        V374     V374.1  \
# count  357.000000  357.000000  352.000000  352.000000  364.000000  364.00000
# mean   230.515406  242.549020  242.355114  260.860795  107.420330  112.42033
# std      9.865267   12.244741   15.875819   14.581354    4.725142    3.16780
# min    213.000000  213.000000  224.000000  224.000000   99.000000   99.00000
# 25%    225.000000  233.000000  228.000000  260.000000  101.000000  111.00000
# 50%    233.000000  241.000000  234.000000  262.000000  109.000000  113.00000
# 75%    237.000000  249.000000  260.000000  268.000000  111.000000  115.00000
# max    266.000000  274.000000  277.000000  281.000000  115.000000  117.00000
#
#              V402      V402.1  VV-C01.424  VV-C01.424.1  ...   REN161A12  \
# count  365.000000  365.000000  367.000000    367.000000  ...  357.000000
# mean    80.619178   84.098630  174.419619    177.831063  ...  293.114846
# std      2.650972    3.261686    3.358937      2.234556  ...    4.576531
# min     75.000000   75.000000  169.000000    169.000000  ...  288.000000
# 25%     79.000000   81.000000  169.000000    176.000000  ...  290.000000
# 50%     81.000000   83.000000  176.000000    178.000000  ...  292.000000
# 75%     81.000000   88.000000  176.000000    178.000000  ...  296.000000
# max     88.000000   94.000000  180.000000    182.000000  ...  312.000000
#
#        REN161A12.1   REN162B09  REN162B09.1  VV-C08.618  VV-C08.618.1  \
# count   357.000000  345.000000   345.000000  335.000000    335.000000
# mean    300.450980  193.028986   194.918841  184.134328    188.316418
# std       6.617646    2.779551     1.222045    3.344025      2.883185
# min     288.000000  184.000000   186.000000  176.000000    178.000000
# 25%     296.000000  193.000000   195.000000  182.000000    187.000000
# 50%     298.000000  193.000000   195.000000  184.000000    188.000000
# 75%     306.000000  195.000000   195.000000  186.000000    190.000000
# max     312.000000  197.000000   197.000000  190.000000    196.000000
#
#           VV-CPH2   VV-CPH2.1        V502      V502.1
# count  360.000000  360.000000  357.000000  357.000000
# mean    91.577778   92.766667   86.969188   88.565826
# std      0.907754    1.112602    2.008872    3.390214
# min     91.000000   91.000000   82.000000   82.000000
# 25%     91.000000   93.000000   86.000000   86.000000
# 50%     91.000000   93.000000   86.000000   88.000000
# 75%     93.000000   93.000000   88.000000   88.000000
# max     93.000000   95.000000   97.000000   97.000000
#
# [8 rows x 32 columns]

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ## Missing values

# %% [markdown]
# Cel ustalenie jakie wystepuja w danych, rodzaje missing values :
# - Missing Completely at Random **MCAR**
# - Missing at Random **MAR**
# - Missing Not at Random **MNAR**

# %% [markdown]
# Liczba missing values łacznie, pamiętamy ze mamy do kazdej mikrosatelity podtyp.

# %%
missing_all=microsatellites.isna().sum().sum()
missing_microsat=missing_all/2
missing_microsat
# Out:
# 270.0

# %% [markdown]
# ### Wizualizacja missing values

# %%
msno.matrix(microsatellites)
# Out:
# <Axes: >

# %% [markdown]
# Widac ze pomiedzy tymi samymi podtypami lokus mikrosatelit (czyli te z oryginalna nazwa i te co maja ".1" na koncu) wystepuje wspolne NaN.

# %%
msno.heatmap(microsatellites)
# Out:
# <Axes: >

# %% [markdown]
# Dla podtypów lokus odpowiadających mikrosatelit korelacja wyniosła wartość równą 1, co świadczy o doskonałej korelacji dodatniej między dwiema zmiennymi. Oznacza to, że kiedy w jednej kolumnie brakuje danych to jednocześnie w drugiej kolumnie również brakuje danych, i odwrotnie.

# %% [markdown]
# Wysokie wartości korelacji równe 0,6 zauważalne są również między dwoma parami markerów: „VV-C01.424.1” oraz „V402.1”, „VVM124.1” oraz „VVINU055.1”. Wymienione powyżej markery są przykładami braków nielosowych. Pozostałe korelacje uzyskały niskie wartości bliskie zeru co świadczy o znikomej zależności, zostały uznane jako braki całkowicie losowe.

# %% [markdown]
# Wizualizacja mikrosatelit o korelacji 0.6

# %%
msno.matrix(microsatellites[['VV-C01.424.1','V402.1','VVM124.1','VVINU055.1']])
# Out:
# <Axes: >

# %% [markdown]
# ### Usunięcie poszczegolnych missing values

# %% [markdown]
# Wyliczenie procentowej sumy missing values w poszczegolnych mikrosatelitach.

# %%
precent_nan=round((microsatellites.isna().sum() * 100/ microsatellites.shape[0]),2)
print(precent_nan.sort_values())
# Out:
# VV-CPH11.1       0.27
# VV-CPH11         0.27
# FH2541.1         1.60
# FH2541           1.60
# VV-C01.424       1.87
# VV-C01.424.1     1.87
# VVINU055         2.14
# VVINU055.1       2.14
# V402             2.41
# V402.1           2.41
# V374             2.67
# V374.1           2.67
# VVM124           2.94
# VVM124.1         2.94
# VV-CPH2          3.74
# VV-CPH2.1        3.74
# DGN3.1           4.01
# DGN3             4.01
# REN161A12        4.55
# REN161A12.1      4.55
# DGN14            4.55
# DGN14.1          4.55
# V502             4.55
# V502.1           4.55
# REN69B24.1       5.88
# REN69B24         5.88
# REN162B09        7.75
# REN162B09.1      7.75
# VV-C08.618      10.43
# VV-C08.618.1    10.43
# VVM189.1        12.83
# VVM189          12.83
# dtype: float64

# %% [markdown]
# Najwięcej missing values wykryto u „REN162B09.1”, „VV-C08.618.1”, „VVM189.1”

# %% [markdown]
# Wyznaczenie missing values ponizej 3%.

# %%
precent_nan[precent_nan<=3].sort_values()
# Out:
# VV-CPH11        0.27
# VV-CPH11.1      0.27
# FH2541          1.60
# FH2541.1        1.60
# VV-C01.424      1.87
# VV-C01.424.1    1.87
# VVINU055        2.14
# VVINU055.1      2.14
# V402            2.41
# V402.1          2.41
# V374            2.67
# V374.1          2.67
# VVM124          2.94
# VVM124.1        2.94
# dtype: float64

# %% [markdown]
# Wyznaczenie missing values powyzej 3%.

# %%
precent_nan[precent_nan>3].sort_values()
# Out:
# VV-CPH2.1        3.74
# VV-CPH2          3.74
# DGN3.1           4.01
# DGN3             4.01
# DGN14            4.55
# REN161A12.1      4.55
# V502             4.55
# REN161A12        4.55
# DGN14.1          4.55
# V502.1           4.55
# REN69B24.1       5.88
# REN69B24         5.88
# REN162B09        7.75
# REN162B09.1      7.75
# VV-C08.618      10.43
# VV-C08.618.1    10.43
# VVM189          12.83
# VVM189.1        12.83
# dtype: float64

# %% [markdown]
# Podjęto decyzję o usunięciu obserwacji dla wartości brakujących mikrosatelit, których braki stanowią nie więcej niż 3% danych z pominięciem mikrosatelit, które uzyskały wysokie wartości korelacji oraz te które miały z nimi wspólne braki. Do mikrosatelit, które spełniły warunki należą: „VV-CPH11.1”, „FH2541.1”, „V374.1”.

# %%
micro_podropie = microsatellites.dropna(subset=['VV-CPH11.1','FH2541.1','V374.1'],how='any')
micro_podropie.describe()
# Out:
#             DGN14     DGN14.1    REN69B24  REN69B24.1        V374      V374.1  \
# count  341.000000  341.000000  335.000000  335.000000  357.000000  357.000000
# mean   230.656891  242.818182  242.447761  261.083582  107.481793  112.445378
# std      9.931953   12.265773   15.806733   14.512194    4.705105    3.118531
# min    213.000000  213.000000  224.000000  224.000000   99.000000   99.000000
# 25%    225.000000  233.000000  228.000000  260.000000  101.000000  111.000000
# 50%    233.000000  241.000000  234.000000  262.000000  110.000000  113.000000
# 75%    237.000000  249.000000  260.000000  268.000000  111.000000  115.000000
# max    266.000000  274.000000  277.000000  281.000000  115.000000  117.000000
#
#              V402      V402.1  VV-C01.424  VV-C01.424.1  ...   REN161A12  \
# count  348.000000  348.000000  350.000000    350.000000  ...  343.000000
# mean    80.600575   84.109195  174.425714    177.862857  ...  293.148688
# std      2.648190    3.269742    3.348681      2.258012  ...    4.611014
# min     75.000000   75.000000  169.000000    169.000000  ...  288.000000
# 25%     79.000000   81.000000  169.000000    176.000000  ...  290.000000
# 50%     81.000000   83.000000  176.000000    178.000000  ...  292.000000
# 75%     81.000000   88.000000  176.000000    180.000000  ...  296.000000
# max     88.000000   94.000000  180.000000    182.000000  ...  312.000000
#
#        REN161A12.1   REN162B09  REN162B09.1  VV-C08.618  VV-C08.618.1  \
# count   343.000000  330.000000   330.000000  320.000000    320.000000
# mean    300.457726  192.996970   194.930303  184.121875    188.268750
# std       6.654185    2.792193     1.137102    3.343570      2.873993
# min     288.000000  184.000000   186.000000  176.000000    178.000000
# 25%     296.000000  193.000000   195.000000  182.000000    186.000000
# 50%     298.000000  193.000000   195.000000  184.000000    188.000000
# 75%     305.000000  195.000000   195.000000  186.000000    190.000000
# max     312.000000  195.000000   197.000000  190.000000    196.000000
#
#           VV-CPH2   VV-CPH2.1        V502      V502.1
# count  344.000000  344.000000  340.000000  340.000000
# mean    91.569767   92.755814   86.967647   88.576471
# std      0.904033    1.116388    2.037006    3.395734
# min     91.000000   91.000000   82.000000   82.000000
# 25%     91.000000   93.000000   86.000000   86.000000
# 50%     91.000000   93.000000   86.000000   88.000000
# 75%     93.000000   93.000000   88.000000   88.000000
# max     93.000000   95.000000   97.000000   97.000000
#
# [8 rows x 32 columns]

# %% [markdown]
# Szybkie porównanie danych przed i po usunieciu missing values

# %%
microsatellites.describe()
# Out:
#             DGN14     DGN14.1    REN69B24  REN69B24.1        V374     V374.1  \
# count  357.000000  357.000000  352.000000  352.000000  364.000000  364.00000
# mean   230.515406  242.549020  242.355114  260.860795  107.420330  112.42033
# std      9.865267   12.244741   15.875819   14.581354    4.725142    3.16780
# min    213.000000  213.000000  224.000000  224.000000   99.000000   99.00000
# 25%    225.000000  233.000000  228.000000  260.000000  101.000000  111.00000
# 50%    233.000000  241.000000  234.000000  262.000000  109.000000  113.00000
# 75%    237.000000  249.000000  260.000000  268.000000  111.000000  115.00000
# max    266.000000  274.000000  277.000000  281.000000  115.000000  117.00000
#
#              V402      V402.1  VV-C01.424  VV-C01.424.1  ...   REN161A12  \
# count  365.000000  365.000000  367.000000    367.000000  ...  357.000000
# mean    80.619178   84.098630  174.419619    177.831063  ...  293.114846
# std      2.650972    3.261686    3.358937      2.234556  ...    4.576531
# min     75.000000   75.000000  169.000000    169.000000  ...  288.000000
# 25%     79.000000   81.000000  169.000000    176.000000  ...  290.000000
# 50%     81.000000   83.000000  176.000000    178.000000  ...  292.000000
# 75%     81.000000   88.000000  176.000000    178.000000  ...  296.000000
# max     88.000000   94.000000  180.000000    182.000000  ...  312.000000
#
#        REN161A12.1   REN162B09  REN162B09.1  VV-C08.618  VV-C08.618.1  \
# count   357.000000  345.000000   345.000000  335.000000    335.000000
# mean    300.450980  193.028986   194.918841  184.134328    188.316418
# std       6.617646    2.779551     1.222045    3.344025      2.883185
# min     288.000000  184.000000   186.000000  176.000000    178.000000
# 25%     296.000000  193.000000   195.000000  182.000000    187.000000
# 50%     298.000000  193.000000   195.000000  184.000000    188.000000
# 75%     306.000000  195.000000   195.000000  186.000000    190.000000
# max     312.000000  197.000000   197.000000  190.000000    196.000000
#
#           VV-CPH2   VV-CPH2.1        V502      V502.1
# count  360.000000  360.000000  357.000000  357.000000
# mean    91.577778   92.766667   86.969188   88.565826
# std      0.907754    1.112602    2.008872    3.390214
# min     91.000000   91.000000   82.000000   82.000000
# 25%     91.000000   93.000000   86.000000   86.000000
# 50%     91.000000   93.000000   86.000000   88.000000
# 75%     93.000000   93.000000   88.000000   88.000000
# max     93.000000   95.000000   97.000000   97.000000
#
# [8 rows x 32 columns]

# %% [markdown]
# Po usunięciu odpowiednich obserwacji obliczono różnice odchyleń standardowych po i przed zastosowaniem metody w celu sprawdzenia czy sposób ten jest właściwy i nie spowoduje usunięcie zbyt dużej ilości danych.

# %%
std_podropie = micro_podropie.std()
std=microsatellites.std()
std_diff_con=round(abs(std_podropie-std),2).sort_values()
std_diff_con=std_diff_con[std_diff_con>=0.05] #wybranie wartości wylacznie równych lub powyzej 0.05
std_diff_con
# Out:
# V374.1         0.05
# VVINU055       0.05
# FH2541.1       0.06
# REN69B24.1     0.07
# REN69B24       0.07
# DGN14          0.07
# DGN3.1         0.08
# REN162B09.1    0.08
# DGN3           0.16
# dtype: float64

# %% [markdown]
# Wartości różnic odchylenia standardowego były niewielkie, gdzie wyłącznie jedna mikrosatelita „DGN3” przekroczyła wartość 0,1.

# %% [markdown]
# Nastepnie wyliczono ile w procentach usunieto danych.

# %%
percent_podropie=micro_podropie.shape[0]*100/microsatellites.shape[0]
print(round(100-percent_podropie,3))
# Out:
# 4.545

# %% [markdown]
# Zapisanie do pliku excel

# %%
std_diff_con_df = pd.DataFrame(std_diff_con, columns=['diff'])
sorted_df = std_diff_con_df.sort_values(by='diff')
sorted_df.to_excel('std_diff_con_df.xlsx')

# %% [markdown]
# Sprawdzenie czy usuniecie poszczegolnych danyc sie udalo

# %%
microsatellites=microsatellites.dropna(subset=['VV-CPH11.1','FH2541.1','V374.1'],how='any')
microsatellites.isna().sum()
# Out:
# DGN14           16
# DGN14.1         16
# REN69B24        22
# REN69B24.1      22
# V374             0
# V374.1           0
# V402             9
# V402.1           9
# VV-C01.424       7
# VV-C01.424.1     7
# VVM189          47
# VVM189.1        47
# FH2541           0
# FH2541.1         0
# VV-CPH11         0
# VV-CPH11.1       0
# VVINU055         7
# VVINU055.1       7
# VVM124           9
# VVM124.1         9
# DGN3            15
# DGN3.1          15
# REN161A12       14
# REN161A12.1     14
# REN162B09       27
# REN162B09.1     27
# VV-C08.618      37
# VV-C08.618.1    37
# VV-CPH2         13
# VV-CPH2.1       13
# V502            17
# V502.1          17
# dtype: int64

# %% [markdown]
# ### Imputacja missing values

# %% [markdown]
# Pozostałe brakujące wartości analizowanych danych zastąpiono metodą MICE oraz wartościami średnich wartości dla podanych zmiennych w celu zidentyfikowania lepszej metody.

# %% [markdown]
# Zauważalne są niewielkie różnice w wyestymowanych wartościach odchylenia standardowego między dwiema zastosowanymi metodami. Ze względu na mniejsze wartości zdecydowano się na imputacje MICE.

# %% [markdown]
# #### MICE

# %%
from fancyimpute import IterativeImputer
microsatellites_MICE= microsatellites.copy(deep=True)
MICE_imputer= IterativeImputer()
microsatellites.iloc[:,:]=MICE_imputer.fit_transform(microsatellites_MICE)

# %% [markdown]
# Sprawdzenie czy imputacja sie powiodła

# %%
microsatellites.isna().sum()
# Out:
# DGN14           0
# DGN14.1         0
# REN69B24        0
# REN69B24.1      0
# V374            0
# V374.1          0
# V402            0
# V402.1          0
# VV-C01.424      0
# VV-C01.424.1    0
# VVM189          0
# VVM189.1        0
# FH2541          0
# FH2541.1        0
# VV-CPH11        0
# VV-CPH11.1      0
# VVINU055        0
# VVINU055.1      0
# VVM124          0
# VVM124.1        0
# DGN3            0
# DGN3.1          0
# REN161A12       0
# REN161A12.1     0
# REN162B09       0
# REN162B09.1     0
# VV-C08.618      0
# VV-C08.618.1    0
# VV-CPH2         0
# VV-CPH2.1       0
# V502            0
# V502.1          0
# dtype: int64

# %%
microsatellites_MICE.describe()
# Out:
#             DGN14     DGN14.1    REN69B24  REN69B24.1        V374      V374.1  \
# count  341.000000  341.000000  335.000000  335.000000  357.000000  357.000000
# mean   230.656891  242.818182  242.447761  261.083582  107.481793  112.445378
# std      9.931953   12.265773   15.806733   14.512194    4.705105    3.118531
# min    213.000000  213.000000  224.000000  224.000000   99.000000   99.000000
# 25%    225.000000  233.000000  228.000000  260.000000  101.000000  111.000000
# 50%    233.000000  241.000000  234.000000  262.000000  110.000000  113.000000
# 75%    237.000000  249.000000  260.000000  268.000000  111.000000  115.000000
# max    266.000000  274.000000  277.000000  281.000000  115.000000  117.000000
#
#              V402      V402.1  VV-C01.424  VV-C01.424.1  ...   REN161A12  \
# count  348.000000  348.000000  350.000000    350.000000  ...  343.000000
# mean    80.600575   84.109195  174.425714    177.862857  ...  293.148688
# std      2.648190    3.269742    3.348681      2.258012  ...    4.611014
# min     75.000000   75.000000  169.000000    169.000000  ...  288.000000
# 25%     79.000000   81.000000  169.000000    176.000000  ...  290.000000
# 50%     81.000000   83.000000  176.000000    178.000000  ...  292.000000
# 75%     81.000000   88.000000  176.000000    180.000000  ...  296.000000
# max     88.000000   94.000000  180.000000    182.000000  ...  312.000000
#
#        REN161A12.1   REN162B09  REN162B09.1  VV-C08.618  VV-C08.618.1  \
# count   343.000000  330.000000   330.000000  320.000000    320.000000
# mean    300.457726  192.996970   194.930303  184.121875    188.268750
# std       6.654185    2.792193     1.137102    3.343570      2.873993
# min     288.000000  184.000000   186.000000  176.000000    178.000000
# 25%     296.000000  193.000000   195.000000  182.000000    186.000000
# 50%     298.000000  193.000000   195.000000  184.000000    188.000000
# 75%     305.000000  195.000000   195.000000  186.000000    190.000000
# max     312.000000  195.000000   197.000000  190.000000    196.000000
#
#           VV-CPH2   VV-CPH2.1        V502      V502.1
# count  344.000000  344.000000  340.000000  340.000000
# mean    91.569767   92.755814   86.967647   88.576471
# std      0.904033    1.116388    2.037006    3.395734
# min     91.000000   91.000000   82.000000   82.000000
# 25%     91.000000   93.000000   86.000000   86.000000
# 50%     91.000000   93.000000   86.000000   88.000000
# 75%     93.000000   93.000000   88.000000   88.000000
# max     93.000000   95.000000   97.000000   97.000000
#
# [8 rows x 32 columns]

# %% [markdown]
# Porównanie danych przed i po imputacji.

# %%
microsatellites.describe()
# Out:
#             DGN14     DGN14.1    REN69B24  REN69B24.1        V374      V374.1  \
# count  357.000000  357.000000  357.000000  357.000000  357.000000  357.000000
# mean   230.653739  242.821090  242.390787  261.097452  107.481793  112.445378
# std      9.714279   11.993909   15.325873   14.061702    4.705105    3.118531
# min    213.000000  213.000000  224.000000  224.000000   99.000000   99.000000
# 25%    225.000000  233.000000  228.000000  260.000000  101.000000  111.000000
# 50%    232.000000  241.000000  239.867954  262.000000  110.000000  113.000000
# 75%    237.000000  249.000000  260.000000  268.000000  111.000000  115.000000
# max    266.000000  274.000000  277.000000  281.000000  115.000000  117.000000
#
#              V402      V402.1  VV-C01.424  VV-C01.424.1  ...   REN161A12  \
# count  357.000000  357.000000  357.000000    357.000000  ...  357.000000
# mean    80.597247   84.108059  174.431362    177.871369  ...  293.121228
# std      2.616772    3.229263    3.317461      2.236983  ...    4.525716
# min     75.000000   75.000000  169.000000    169.000000  ...  288.000000
# 25%     79.000000   81.000000  169.000000    176.000000  ...  290.000000
# 50%     81.000000   83.000000  176.000000    178.000000  ...  292.000000
# 75%     81.000000   88.000000  176.000000    180.000000  ...  296.000000
# max     88.000000   94.000000  180.000000    182.000000  ...  312.000000
#
#        REN161A12.1   REN162B09  REN162B09.1  VV-C08.618  VV-C08.618.1  \
# count   357.000000  357.000000   357.000000  357.000000    357.000000
# mean    300.427747  192.993684   194.943791  184.109173    188.255006
# std       6.534379    2.684341     1.097858    3.168587      2.727840
# min     288.000000  184.000000   186.000000  176.000000    178.000000
# 25%     296.000000  193.000000   195.000000  182.000000    187.805104
# 50%     299.801223  193.000000   195.000000  184.000000    188.000000
# 75%     304.000000  195.000000   195.000000  186.000000    190.000000
# max     312.000000  195.000000   197.000000  190.000000    196.000000
#
#           VV-CPH2   VV-CPH2.1        V502      V502.1
# count  357.000000  357.000000  357.000000  357.000000
# mean    91.569453   92.755698   86.957391   88.556772
# std      0.887428    1.095829    1.991439    3.322318
# min     91.000000   91.000000   82.000000   82.000000
# 25%     91.000000   92.795958   86.000000   86.000000
# 50%     91.000000   93.000000   86.000000   88.000000
# 75%     93.000000   93.000000   88.000000   88.000000
# max     93.000000   95.000000   97.000000   97.000000
#
# [8 rows x 32 columns]

# %% [markdown]
# Porównano różnice odchylenia standardowego po i przed imputacją.

# %%
MICE_std_diff=round(abs(microsatellites_MICE.std()-microsatellites.std()),2).sort_values()
MICE_std_diff_cond=MICE_std_diff[MICE_std_diff>0.1]
MICE_std_diff_cond
# Out:
# REN162B09       0.11
# REN161A12.1     0.12
# VV-C08.618.1    0.15
# VV-C08.618      0.17
# DGN14           0.22
# DGN3.1          0.25
# DGN3            0.26
# DGN14.1         0.27
# VVM189.1        0.37
# VVM189          0.38
# REN69B24.1      0.45
# REN69B24        0.48
# dtype: float64

# %% [markdown]
# Zapisanie do pliku excel.

# %%
MICE_std_diff_df = pd.DataFrame(MICE_std_diff_cond, columns=['mice_std'])
MICE_std_diff_df.to_excel('MICE_std_diff_df.xlsx')

# %% [markdown]
# #### MEAN

# %%
from sklearn.impute import SimpleImputer
mean_microsatellites=microsatellites.copy(deep=True)
mean_imputer = SimpleImputer(strategy='mean')
mean_microsatellites.iloc[:,:] = mean_imputer.fit_transform(mean_microsatellites)

# %%
mean_std_diff=round(abs(mean_microsatellites.std()-microsatellites.std()),2).sort_values()
mean_std_diff_cond=mean_std_diff[mean_std_diff>0.1]
mean_std_diff_cond
# Out:
# Series([], dtype: float64)

# %%
meanimp_std_diff_df = pd.DataFrame(mean_std_diff_cond, columns=['mean_imputation_std'])
meanimp_std_diff_df.to_excel('meanimp_std_diff_df.xlsx')

# %% [markdown]
# ## Usuniecie wartości odstajacych

# %%
import plotly.express as px
fig = px.scatter_mapbox(coordinates,
                     lat='Latitude',
                     lon='Longitude',
                     zoom=3)


fig.update_layout(mapbox_style='carto-positron',
                    margin={'r': 10, 't': 10, 'l': 10, 'b': 10})
fig.show()

# %%
def outliers(data,feature):
        final_data = data.copy()
        Q1 = data[feature].quantile(0.25)
        Q3 = data[feature].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = data[(data[feature] < (lower_bound)) | (data[feature] > (upper_bound))]
        final_data = final_data[(final_data[feature] >= lower_bound) & (final_data[feature] <= upper_bound)]
        percent = round(len(outliers)*100/len(data),3)
        print(f'Number of outliers: {len(outliers)}\nNumber of observations: {len(data)}\nPercent of outliers: {percent}')
        return final_data, outliers

# %%
coord_cleaned,coord_outliers1=outliers(coordinates,'Longitude')
# Out:
# Number of outliers: 29
# Number of observations: 374
# Percent of outliers: 7.754

# %%
coord_cleaned,coord_outliers1=outliers(coord_cleaned,'Latitude')
# Out:
# Number of outliers: 39
# Number of observations: 345
# Percent of outliers: 11.304

# %%
fig = px.scatter_mapbox(coord_cleaned,
                     lat='Latitude',
                     lon='Longitude',
                     zoom=3)


fig.update_layout(mapbox_style='carto-positron',
                    margin={'r': 10, 't': 10, 'l': 10, 'b': 10})
fig.show()

# %%
(26+37)*100/357
# Out:
# 17.647058823529413

# %% [markdown]
# Usuniecie 17,65% danych

# %% [markdown]
# ## Analiza korelacji oraz rozkładu danych

# %% [markdown]
# ### Rozklad danych

# %%
col_names_dot = [col for col in microsatellites.columns if col.endswith('.1')]
MICRO_DOT=microsatellites[col_names_dot]
axes=MICRO_DOT.plot(kind='density', subplots=True,layout=(-1, 3), sharex=False, figsize=(15,15))
axes = axes.flatten()

for ax in axes:
    ax.set_ylabel('') 
plt.show()

# %%
MICRO_DOT.hist(figsize=(10, 10))
plt.show()

# %% [markdown]
# Wstępna wizualizacja danych dotyczących mikrosatelit wykazała obecność rozkładów kształtów niestandardowych. W celu uzyskania pewności, że żadna zmienna nie wykazuję rozkładu normalnego wykonano test Shapiro-Wilka przy poziomie istotności 5%, gdzie hipoteza zerowa zakłada, że dane pochodzą z rozkładu normalnego.

# %%
results_list = []
col_names_dot = [col for col in microsatellites.columns if col.endswith('.1')]

for col in col_names_dot:
    stat, p = shapiro(microsatellites[col])
    results_list.append({'mikrosatelita': col, 'stat': round(stat,3), 'p-value': p})

shapiro_results = pd.DataFrame(results_list)
shapiro_results
# Out:
#    mikrosatelita   stat       p-value
# 0        DGN14.1  0.970  9.127413e-07
# 1     REN69B24.1  0.866  5.254763e-17
# 2         V374.1  0.824  1.914541e-19
# 3         V402.1  0.888  1.780305e-15
# 4   VV-C01.424.1  0.840  1.353815e-18
# 5       VVM189.1  0.921  8.460761e-13
# 6       FH2541.1  0.855  1.094825e-17
# 7     VV-CPH11.1  0.516  4.265926e-30
# 8     VVINU055.1  0.908  6.441845e-14
# 9       VVM124.1  0.904  2.892969e-14
# 10        DGN3.1  0.894  5.079686e-15
# 11   REN161A12.1  0.940  8.222978e-11
# 12   REN162B09.1  0.591  3.702255e-28
# 13  VV-C08.618.1  0.924  1.562395e-12
# 14     VV-CPH2.1  0.734  1.736930e-23
# 15        V502.1  0.726  7.946846e-24

# %% [markdown]
# Wartość p-value dla wszystkich mikrosatelit wyniosła poniżej 0,05 w wyniku czego odrzucono dla każdej hipotezę zerową co świadczy o braku rozkładu normalnego.

# %% [markdown]
# Wyniki zapisano do pliku excel.

# %%
shapiro_results.to_excel('shapiro_results.xlsx')

# %% [markdown]
# ### Korelacja

# %% [markdown]
# Z powodu braku rozkładu normalnego wśród analizowanych danych zastosowano korelacje Spearmana.

# %%
col_names_dot = [col for col in microsatellites.columns if col.endswith('.1')]

correlation_matrix = microsatellites[col_names_dot].corr(method='spearman')
correlation_df = pd.DataFrame(correlation_matrix, index=col_names_dot, columns=col_names_dot)

mask = np.triu(np.ones_like(correlation_df, dtype=bool))
sns.set(style="white")
plt.figure(figsize=(15, 15))
sns.heatmap(correlation_df, annot=True, cmap='coolwarm', fmt='.2f', square=True, cbar_kws={"shrink": .82}, linewidths=.5, mask=mask)
plt.show()

# %% [markdown]
# Porównano wartości korelacji między mikrosatelitami, gdzie najwyższa wartość osiągnęła 0,28 natomiast najniższa -0,14. Wartości tak bliskie zeru świadczą o znikomej korelacji między zmiennymi.

# %% [markdown]
# Następnie wyliczono wartości korelacji między oryginalną mikrosatelitą, a jej konkretnym podtypem lokus.

# %%
results = []

for col in microsatellites.columns:
    if col.endswith('.1'):
        orig_col = col[:-2]
        if orig_col in microsatellites.columns:
            orgd = microsatellites[orig_col]
            col1 = microsatellites[col]
            spearman_correlation, p_value = stats.spearmanr(orgd, col1)
            results.append({
                'Original Column': orig_col,
                'Compared Column': col,
                'Spearman Correlation': round(spearman_correlation, 3),
                'P-value': p_value
            })

correlation_results_df = pd.DataFrame(results)
sorted_correlation_results_df = correlation_results_df.sort_values(by='Spearman Correlation', ascending=False)

print(sorted_correlation_results_df)
# Out:
#    Original Column Compared Column  Spearman Correlation       P-value
# 15            V502          V502.1                 0.557  1.839348e-30
# 5           VVM189        VVM189.1                 0.520  3.861584e-26
# 0            DGN14         DGN14.1                 0.500  6.002972e-24
# 8         VVINU055      VVINU055.1                 0.483  2.808485e-22
# 2             V374          V374.1                 0.465  1.398372e-20
# 10            DGN3          DGN3.1                 0.453  1.690197e-19
# 3             V402          V402.1                 0.444  1.185657e-18
# 1         REN69B24      REN69B24.1                 0.439  2.728390e-18
# 9           VVM124        VVM124.1                 0.435  6.696023e-18
# 6           FH2541        FH2541.1                 0.422  7.962384e-17
# 13      VV-C08.618    VV-C08.618.1                 0.378  1.351753e-13
# 11       REN161A12     REN161A12.1                 0.358  3.196721e-12
# 4       VV-C01.424    VV-C01.424.1                 0.327  2.489386e-10
# 7         VV-CPH11      VV-CPH11.1                 0.285  4.242854e-08
# 14         VV-CPH2       VV-CPH2.1                 0.284  4.997019e-08
# 12       REN162B09     REN162B09.1                 0.265  3.648140e-07

# %% [markdown]
# Największa wartość wyniosła 0,557 natomiast najmniejsza 0,265 (Tabela 5). Stwierdzono, że wyestymowane wartości są za niskie, aby stwierdzić pewną korelację pomiędzy podanymi mikrosatelitami.

# %%
sorted_correlation_results_df.to_excel('sorted_correlation_results_df.xlsx')

# %%
microsatellites.to_excel('microsatellites.xlsx')

# %% [markdown]
# # Principal component analysis

# %%
pipe = Pipeline([
        ('scaler', StandardScaler()),
        ('reducer',PCA())]) #n_components=.9
after_pca=pipe.fit(microsatellites) #fit_transform
var= pipe['reducer'].explained_variance_ratio_
plt.figure(figsize=(10, 6))
plt.plot(np.arange(1, len(var)+1),var)
plt.xlabel('Numer poszczególnych głównych składowych',labelpad=10)
plt.ylabel('Współczynnik wyjaśnionej wariancji',labelpad=10)
plt.xlim(left=1)
plt.xticks(np.arange(1,34,2))
plt.grid(True)
plt.show()

# %%
features=range(pipe['reducer'].n_components_)
plt.figure(figsize=(10, 6))
plt.bar(np.arange(1, len(var)+1),var)
#plt.xticks(np.arange(1, len(var)+1))
plt.ylabel('Współczynnik wyjaśnionej wariancji',labelpad=10)
plt.xlabel('Numer poszczególnych głównych składowych',labelpad=10)
plt.xticks(np.arange(1,33))
plt.yticks(np.arange(0,0.07,0.01))
plt.xlim(left=-0)
plt.ylim(top=0.075)
plt.grid(True)
plt.show()

# %%
cumulative_var = np.cumsum(var)
plt.figure(figsize=(10, 6))
plt.plot(np.arange(1, len(cumulative_var)+1), cumulative_var)
#plt.plot(cumulative_var*100)
plt.xlabel('Numer poszczególnych głównych składowych',labelpad=10)
plt.ylabel('Skumulowany współczynnik wyjaśnionej wariancji',labelpad=10)
plt.xlim(left=1)
plt.xticks(np.arange(1,34,2))
plt.yticks(np.arange(0,1.1,0.1))
plt.grid(True)
plt.show()

# %%
pipe = Pipeline([
        ('scaler', StandardScaler()),
        ('reducer',PCA(n_components=13))]) 
pca_ready=pipe.fit_transform(microsatellites)

# %%
principal_df = pd.DataFrame(data=pca_ready, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10', 'PC11', 'PC12', 'PC13'])

# %% [markdown]
# # DBSCAN

# %%
gdf = GeoDataFrame(coord_cleaned, geometry=[Point(xy) for xy in zip(coord_cleaned.Longitude, coord_cleaned.Latitude)])
gdf.crs = 'EPSG:4326'

# %%
gdf = gdf.reset_index(drop=True)
gdf[['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10', 'PC11', 'PC12', 'PC13']] = principal_df[['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10', 'PC11', 'PC12', 'PC13']]

# %%
gdf=gdf.dropna()
gdf.isna().sum()
# Out:
# Longitude    0
# Latitude     0
# geometry     0
# PC1          0
# PC2          0
# PC3          0
# PC4          0
# PC5          0
# PC6          0
# PC7          0
# PC8          0
# PC9          0
# PC10         0
# PC11         0
# PC12         0
# PC13         0
# dtype: int64

# %%
gdf.head()
# Out:
#    Longitude   Latitude                   geometry       PC1       PC2  \
# 0  13.356389  52.573250  POINT (13.35639 52.57325) -0.717211  0.428744
# 1  13.356389  52.573250  POINT (13.35639 52.57325)  3.113094  0.336562
# 2  13.387306  52.589056  POINT (13.38731 52.58906) -1.789488  1.866810
# 3  13.632750  52.516000  POINT (13.63275 52.51600) -1.659007 -2.184777
# 4  13.578528  52.412361  POINT (13.57853 52.41236)  1.789680 -0.894133
#
#         PC3       PC4       PC5       PC6       PC7       PC8       PC9  \
# 0 -1.231522  1.386955 -0.083496  0.532792 -1.220683 -0.447963 -0.824316
# 1  0.052321  0.664529  0.530362 -1.351089 -0.448037  0.741026  1.216790
# 2  1.419445  2.959233 -2.639910  0.148990 -0.948874  0.601777 -0.902570
# 3  0.899387 -1.647252 -0.324259  0.295543 -0.369500 -0.342611  0.014226
# 4 -0.491243 -0.048383  0.249901  1.274806 -0.958584  0.044228 -1.109175
#
#        PC10      PC11      PC12      PC13
# 0 -0.051564 -0.919410  0.939840  0.599341
# 1 -0.395249 -0.885882  0.962615 -2.522675
# 2  0.251137  1.702760 -1.085916 -1.698692
# 3 -0.471889 -0.885464 -0.872249 -0.319125
# 4 -0.751626  0.859185  0.345825 -0.124585

# %%
def najblizszychsasiadow(data, neighbors_count,line1,line2):
    neighbors_model = NearestNeighbors(n_neighbors=neighbors_count)
    neighbors_fit = neighbors_model.fit(data)
    distances, indices = neighbors_fit.kneighbors(data)
    sorted_distances = np.sort(distances[:, neighbors_count-1], axis=0)
    fig = plt.figure(figsize=(16,9))
    ax = fig.add_subplot()
    ax.set_xlabel("Sample number")
    ax.set_ylabel("Distance to furthest nearest neighbor")
    ax.plot(sorted_distances)
    #ax.set_yticks(range) 
    ax.axhline(y=line1, linestyle='dashed')
    ax.axhline(y=line2, linestyle='dashed')
    plt.show()

# %%
def evaluate_silhouette_score(data,eps_range, min_samples_range,min_cluster):
    output = []
    for ms in min_samples_range:
        for ep in eps_range:
            labels = DBSCAN(min_samples=ms, eps=ep).fit(data).labels_
            n_clusters = len(np.unique(labels))
            if n_clusters > min_cluster:
                score = sklearn_silhouette_score(data, labels)
                output.append((ms, ep, score))
        
    if output:
        min_samples, eps, score = sorted(output, key=lambda x: x[-1], reverse=True)[0]
        print(f"Best silhouette score: {score}")
        print(f"min_samples: {min_samples}")
        print(f"eps: {eps}")
    else:
        print("DBSCAN failed to produce meaningful clusters for the given parameter range.")

# %%
def dbscan(xy, epsilon, minpoints):
    
    dbsc = DBSCAN(eps=epsilon, min_samples=minpoints).fit(xy)
    labels = dbsc.labels_
    unique_labels = np.unique(labels)
    num_clusters = len(unique_labels) - 1 if -1 in unique_labels else len(unique_labels)
    print(f"Liczba clusters: {num_clusters}")
    
    for cluster_label in unique_labels:
        if cluster_label == -1:
            plt.scatter(xy[labels == cluster_label][:, 0], xy[labels == cluster_label][:, 1], color='black', marker='x', label='Noise')
        else:
            plt.scatter(xy[labels == cluster_label][:, 0], xy[labels == cluster_label][:, 1], label=f'Cluster {cluster_label + 1}')
    
    plt.title("DBSCAN Clustering")
    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.legend()
    plt.show()

# %%
microsat_after_pca = gdf.drop(['Longitude', 'Latitude','geometry'], axis=1)
najblizszychsasiadow(microsat_after_pca,25,5,7.4)

# %%
evaluate_silhouette_score(microsat_after_pca,np.arange(4,8,0.01), range(14,20,1),1)
# Out:
# Best silhouette score: 0.4485478608703836
# min_samples: 14
# eps: 5.629999999999965

# %%
wspolrzedne = gdf[['Longitude', 'Latitude']]
najblizszychsasiadow(wspolrzedne,25,0.149,0.3) #np.arange(0, 1.3, 0.05)

# %%
evaluate_silhouette_score(wspolrzedne,np.arange(0.08,0.56,0.01), range(3,10,1),3)
# Out:
# Best silhouette score: 0.5317353225830904
# min_samples: 3
# eps: 0.14999999999999997

# %%
evaluate_silhouette_score(wspolrzedne,np.arange(0.08,0.56,0.01), range(3,10,1),6)
# Out:
# Best silhouette score: 0.4217230013683953
# min_samples: 5
# eps: 0.09

# %%
dbscan(wspolrzedne, 0.14999, 3)
# Out:
# Liczba clusters: 3

# %%
dbscan(wspolrzedne, 0.09, 5)
# Out:
# Liczba clusters: 6

# %%
microsat_after_pca = microsat_after_pca.to_numpy()
dbscan(microsat_after_pca, 5.6299, 14)
# Out:
# Liczba clusters: 1

# %% [markdown]
# # K-Means

# %%
sse = {}
for k in range(1, 20):
    kmeans = KMeans(n_clusters=k, max_iter=1000, n_init=10).fit(microsat_after_pca)
    sse[k] = kmeans.inertia_

plt.figure(figsize=(10, 6))
plt.plot(list(sse.keys()), list(sse.values()), 'bx-')
plt.xlabel('Number of clusters')
plt.ylabel('Sum of squared distances')
plt.title('Elbow Method For Optimal k')
plt.xticks(range(1, 20))
plt.grid(True)
plt.show()

# %%
silhouette_scores = {}
for k in range(2, 25):
    kmeans = KMeans(n_clusters=k, max_iter=1000, n_init=10).fit(microsat_after_pca)
    score = silhouette_score(microsat_after_pca, kmeans.labels_)
    silhouette_scores[k] = score

plt.figure(figsize=(10, 6))
plt.plot(list(silhouette_scores.keys()), list(silhouette_scores.values()), 'bx-')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score For Different k')
plt.xticks(range(2, 25))
plt.grid(True)
plt.show()
silhouette_scores
# Out:
# {2: 0.06759440118629993,
#  3: 0.06189340340999779,
#  4: 0.06208890568941284,
#  5: 0.06195400023214745,
#  6: 0.06608202580077746,
#  7: 0.06300467386748103,
#  8: 0.06666494532722042,
#  9: 0.06970054181660777,
#  10: 0.06796032412543701,
#  11: 0.0655551180516689,
#  12: 0.07040502958919184,
#  13: 0.07438663431360124,
#  14: 0.07115671730671645,
#  15: 0.07128582075334729,
#  16: 0.07716733905112727,
#  17: 0.07225174417518239,
#  18: 0.06771325392060734,
#  19: 0.07618718460735666,
#  20: 0.06971668825893881,
#  21: 0.06391551839700547,
#  22: 0.0757646848606766,
#  23: 0.06265717304726164,
#  24: 0.06845947216194727}

# %%
gdf_kopia = gdf.copy()
kmeans_final = KMeans(n_clusters=14, max_iter=1000, n_init=10).fit(microsat_after_pca)

gdf_kopia['Cluster'] = kmeans_final.labels_
cluster_distribution = gdf_kopia['Cluster'].value_counts().sort_index()
print(cluster_distribution)
# Out:
# Cluster
# 0     22
# 1     26
# 2     26
# 3     12
# 4     23
# 5     20
# 6     27
# 7      1
# 8     31
# 9     30
# 10    21
# 11    23
# 12    31
# 13    13
# Name: count, dtype: int64

# %%
fig = px.scatter_mapbox(gdf_kopia,
                     lat='Latitude',
                     lon='Longitude',
                     color='Cluster',zoom=3)


fig.update_layout(mapbox_style='carto-positron',
                    margin={'r': 10, 't': 10, 'l': 10, 'b': 10})
fig.show()

# %%
import folium
import branca.colormap as cm

def geo_vis(data, column, zoom_start=3, radius=5, tiles='OpenStreetMap'):
    if not all(x in data.columns for x in ['Latitude', 'Longitude', column]):
        raise ValueError("Dataframe must contain 'Latitude', 'Longitude', and specified 'column'.")

    center_lat = data['Latitude'].mean()
    center_lon = data['Longitude'].mean()
    m = folium.Map(location=[center_lat, center_lon], zoom_start=zoom_start, tiles=tiles)

    colorscale = cm.linear.YlOrRd_09.scale(data[column].min(), data[column].max())

    for _, row in data.iterrows():
        folium.CircleMarker(
            location=[row['Latitude'], row['Longitude']],
            radius=radius,
            fill=True,
            color=colorscale(row[column]),
            fill_color=colorscale(row[column]),
            tooltip=f"{column}: {row[column]}"
        ).add_to(m)

    m.save('map.html')
    return m

# %%
geo_vis(gdf_kopia,'Cluster')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c25b6be6cdb835bf026712419204fbc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c25b6be6cdb835bf026712419204fbc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c25b6be6cdb835bf026712419204fbc = L.map(
#                 &quot;map_7c25b6be6cdb835bf026712419204fbc&quot;,
#                 {
#                     center: [52.484556487145966, 13.344483744952797],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1523f1e24b099eb4362d00977f85e430 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1523f1e24b099eb4362d00977f85e430.addTo(map_7c25b6be6cdb835bf026712419204fbc);
#
#
#             var circle_marker_a7308e6be897a8cf0908a938f33d689e = L.circleMarker(
#                 [52.57325, 13.3563889],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ef3222ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ef3222ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7c25b6be6cdb835bf026712419204fbc);
#
#
#             circle_marker_a7308e6be897a8cf0908a938f33d689e.bindTooltip(
#                 `&lt;div&gt;
#                      Cluster: 9
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_a7d2c64f96569785b7ab503e101243f0 = L.circleMarker(
#                 [52.57325, 13.3563889],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fe9841ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fe9841ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7c25b6be6cdb835bf026712419204fbc);
#
#
#             circle_marker_a7d2c64f96569785b7ab503e101243f0.bindTooltip(
#                 `&lt;div&gt;
#                      Cluster: 6
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_8cd4877d4473e23badee52e193f4aafd = L.circleMarker(
#                 [52.5890556, 13.3873056],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#800026ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#800026ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7c25b6be6cdb835bf026712419204fbc);
#
#
#             circle_marker_8cd4877d4473e23badee52e193f4aafd.bindTooltip(
#                 `&lt;div&gt;
#                      Cluster: 13
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_21abc5f4b94f2bf6d26294b45de777d5 = L.circleMarker(
#                 [52.516, 13.63275],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#a60026ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#a60026ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7c25b6be6cdb835bf026712419204fbc);
#
#
#             circle_marker_21abc5f4b94f2bf6d26294b45de777d5.bindTooltip(
#                 `&lt;div&gt;
#                      Cluster: 12
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_8d5dcbb73eb274fb2e2323251e7629c6 = L.circleMarker(
#                 [52.4123611, 13.5785278],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fec763ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fec763ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;roun

# %% [markdown]
# # Spectral clustering

# %%
spectral_clust = SpectralClustering(n_clusters=14, affinity='nearest_neighbors', assign_labels='kmeans', random_state=42) #9,14, 21
gdf_kopia['SpectralCluster'] = spectral_clust.fit_predict(microsat_after_pca)


spectral_cluster_distribution = gdf_kopia['SpectralCluster'].value_counts().sort_index()
spectral_cluster_distribution
# Out:
# SpectralCluster
# 0     10
# 1     38
# 2     20
# 3     24
# 4     34
# 5     16
# 6     18
# 7     30
# 8     18
# 9     25
# 10    12
# 11    24
# 12    18
# 13    19
# Name: count, dtype: int64

# %%
fig = px.scatter_mapbox(gdf_kopia,
                     lat='Latitude',
                     lon='Longitude',
                     color='SpectralCluster',zoom=3)


fig.update_layout(mapbox_style='carto-positron',
                    margin={'r': 10, 't': 10, 'l': 10, 'b': 10})
fig.show()

# %%
geo_vis(gdf_kopia,'SpectralCluster')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e20199c762f5bff95752ac565951e13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e20199c762f5bff95752ac565951e13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e20199c762f5bff95752ac565951e13 = L.map(
#                 &quot;map_8e20199c762f5bff95752ac565951e13&quot;,
#                 {
#                     center: [52.484556487145966, 13.344483744952797],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f866067f2c1267c960b9667556e8b730 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f866067f2c1267c960b9667556e8b730.addTo(map_8e20199c762f5bff95752ac565951e13);
#
#
#             var circle_marker_ffa7aeefea37dfa414bc9a799b0fe6f9 = L.circleMarker(
#                 [52.57325, 13.3563889],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fec763ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fec763ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8e20199c762f5bff95752ac565951e13);
#
#
#             circle_marker_ffa7aeefea37dfa414bc9a799b0fe6f9.bindTooltip(
#                 `&lt;div&gt;
#                      SpectralCluster: 4
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_3f5a94dfba7c0267392ae9dca54a3cff = L.circleMarker(
#                 [52.57325, 13.3563889],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fff4b1ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fff4b1ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8e20199c762f5bff95752ac565951e13);
#
#
#             circle_marker_3f5a94dfba7c0267392ae9dca54a3cff.bindTooltip(
#                 `&lt;div&gt;
#                      SpectralCluster: 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_3b99deb467f592c83e414ba2debaf608 = L.circleMarker(
#                 [52.5890556, 13.3873056],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffffccff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffffccff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8e20199c762f5bff95752ac565951e13);
#
#
#             circle_marker_3b99deb467f592c83e414ba2debaf608.bindTooltip(
#                 `&lt;div&gt;
#                      SpectralCluster: 0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_b76aae982de6fc8aed3e16b95b46e5c1 = L.circleMarker(
#                 [52.516, 13.63275],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fec763ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fec763ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8e20199c762f5bff95752ac565951e13);
#
#
#             circle_marker_b76aae982de6fc8aed3e16b95b46e5c1.bindTooltip(
#                 `&lt;div&gt;
#                      SpectralCluster: 4
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_cf672fa63115eddb939a1d6720cd96cc = L.circleMarker(
#                 [52.4123611, 13.5785278],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#c60623ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c60623ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &q
